# %% [markdown]
# ### **Definir el directorio de trabajo**
# Define el directorio de trabajo como la carpeta `data` de la carpeta compartida `DS4A-Team12` de Drive.
# Este directorio debe contener el archivo de datos original `Sociodemografico.zip` (5945450 registros, 140 MB) en el directorio `raw_data` y el diccionario de datos `dtypes_sociodemo.json` en el directorio `data_dictionaries`.

# %%
import os
import sys
from google.colab import drive 
# Enlazar a la carpeta 'data'
drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/Colab Notebooks/ICBF/data')
sys.path.insert(0, '../scripts/0_utils')
# !pwd
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/ICBF/data

# %%
# Librerias relevantes
import time
import pandas as pd
import numpy as np
import json
import joblib

# %% [markdown]
# ### **Lectura del archivo**

# %%
time0 = time.time()
# Abre el diccionario con la estructura de datos definida
with open('datatypes_dictionaries/dtypes_vars_toma.json', 'r') as file:
  dtypes_vars_toma = json.load(file)
# Diccionario con categorías válidas (ordenadas) para cada variable categórica (ordinal)
with open('datatypes_dictionaries/tom_cat.json', 'r') as file:
  tom_cat = json.load(file)
with open('datatypes_dictionaries/dtypes_sociodemo.json', 'r') as file:
  dtypes_soc = json.load(file)
# Lee el archivo
tom = pd.read_parquet('clean_data/tomas.parquet')
tom = tom.astype(dtypes_vars_toma)
tom.info()

soc = pd.read_parquet('clean_data/sociodemo_filtered.parquet')
soc = soc.astype(dtypes_soc)
soc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19275081 entries, 0 to 19275080
# Data columns (total 27 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   IdToma                          UInt32
#  1   Registro                        UInt32
#  2   Vigencia                        category
#  3   Toma                            category
#  4   Servicio                        category
#  5   FechaValoracionNutricional      datetime64[ns]
#  6   EdadMeses                       float32
#  7   FechaMedicionPerimetroBraquial  datetime64[ns]
#  8   MedicionPerimetroBraquial       float32
#  9   Peso                            float32
#  10  Talla                           float32
#  11  ZScoreTallaEdad                 float32
#  12  ZScorePesoEdad                  float32
#  13  ZScorePesoTalla                 float32
#  14  ZScoreIMC                       float32
#  15  EstadoTallaEdad                 category
#  16  EstadoPesoEdad                  category
#  17  EstadoPesoTalla                 category
#  18  EstadoIMC                       category
#  19  Flag                            UInt8
#  20  FechaRegistroSaludNutricion     datetime64[ns]
#  21  PresentaCarneVacunacion         category
#  22  ControlesCrecimDesarrollo       UInt8
#  23  AntecedentePremadurez           category
#  24  Direccion                       category
#  25  IdBeneficiario                  UInt32
#  26  Id                              UInt32
# dtypes: UInt32(4), UInt8(2), category(10), datetime64[ns](3), float32(8)
# memory usage: 1.6 GB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1508999 entries, 2 to 5945349
# Data columns (total 68 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   Cod_clase                  1508999 non-null  category
#  1   Ind_grupo_sisben_4         1508999 non-null  category
#  2   Ind_nivel_sisben_4         1508999 non-null  category
#  3   Tip_vivienda               1508999 non-null  category
#  4   Ind_tiene_energia          1508999 non-null  category
#  5   Ind_tiene_alcantarillado   1508999 non-null  category
#  6   Ind_tiene_gas              1508999 non-null  category
#  7   Ind_tiene_recoleccion      1508999 non-null  category
#  8   Ind_tiene_acueducto        1508999 non-null  category
#  9   n_hogares_vivienda         1508999 non-null  UInt8
#  10  Tip_ocupa_vivienda         1508999 non-null  category
#  11  Ind_tiene_cocina           1508999 non-null  category
#  12  Ind_tiene_nevera           1508999 non-null  category
#  13  Ind_tiene_lavadora         1508999 non-null  category
#  14  Ind_tiene_pc               1508999 non-null  category
#  15  Ind_tiene_internet         1508999 non-null  category
#  16  n_personas_hogar           1508999 non-null  UInt8
#  17  Sexo                       1508998 non-null  category
#  18  Ind_ninguna_discapac       1508999 non-null  category
#  19  Tip_seg_social             1508999 non-null  category
#  20  Ind_acudio_salud           170136 non-null   category
#  21  Ind_fue_atendido_salud     145227 non-null   category
#  22  Tip_cuidado_ninos          1508999 non-null  category
#  23  Ind_recibe_comida          1069958 non-null  category
#  24  Ind_leer_escribir          439041 non-null   category
#  25  Ind_estudia                1508999 non-null  category
#  26  privado_logro_educ         1508999 non-null  category
#  27  privado_analfabe           1508999 non-null  category
#  28  privado_inasistencia       1508999 non-null  category
#  29  privado_rezago             1508999 non-null  category
#  30  privado_primera_inf        1508999 non-null  category
#  31  privado_trabajo_inf        1508999 non-null  category
#  32  privado_desemp_largo       1508999 non-null  category
#  33  privado_trabajo_info       1508999 non-null  category
#  34  privado_aseguram           1508999 non-null  category
#  35  privado_acceso_salud       1508999 non-null  category
#  36  privado_agua               1508999 non-null  category
#  37  privado_excreta            1508999 non-null  category
#  38  privado_suelo              1508999 non-null  category
#  39  privado_pared              1508999 non-null  category
#  40  privado_hacina             1508999 non-null  category
#  41  n_privaciones              1508999 non-null  float32
#  42  IndicadorPobrezaMulti      1508999 non-null  category
#  43  ingresos_promP_imp         1508999 non-null  float32
#  44  gasto_ppers_imp            1508999 non-null  float32
#  45  gasto_alim_ppers_imp       1508999 non-null  float32
#  46  porc_gasto_alim            1508999 non-null  float32
#  47  union_temprana             1508999 non-null  category
#  48  n_ninos                    1508999 non-null  UInt8
#  49  Tip_hijo                   1508999 non-null  category
#  50  Jefat_fem                  1508999 non-null  category
#  51  Tip_familia                1508999 non-null  category
#  52  Genera_ingresos            1508999 non-null  category
#  53  Nivel_educ_padre           931333 non-null   category
#  54  Nivel_educ_madre           1440178 non-null  category
#  55  anno_encuesta              1508999 non-null  category
#  56  Uni_dias_agua              1508999 non-null  float32
#  57  Ind_afec_evento_natural    1508999 non-null  category
#  58  n_afec_evento_natural      1508999 non-null  UInt8
#  59  Edad_padres_mayor          1508999 non-null  UInt8
#  60  Edad_padres_menor          1508999 non-null  UInt8
#  61  Comparte_cocina_sanitario  1508999 non-null  category
#  62  Estrato                    1508999 non-null  category
#  63  cod_mpio                   1508999 non-null  category
#  64  cod_dpto                   1508999 non-null  category
#  65  FechaNacimiento            1508999 non-null  datetime64[ns]
#  66  IdBeneficiario             1508999 non-null  UInt32
#  67  Id                         1508999 non-null  UInt32
# dtypes: UInt32(2), UInt8(6), category(53), datetime64[ns](1), float32(6)
# memory usage: 167.0 MB

# %%
primera_toma = pd.read_parquet('auxiliary_data/beneficiario_primera_toma.parquet')
reincidencia = pd.read_parquet('clean_data/tagged_data')

# %%
# Lista de variables categóricas
cols_cat = [col for col in tom.columns if col in tom_cat.keys()]
# Lista de variables categóricas ordinales
cols_ord = ['Vigencia', 'Toma', 
            'EstadoTallaEdad', 'EstadoPesoEdad', 'EstadoPesoTalla', 'EstadoIMC']
cols_fecha = [col for col in tom.columns if col[:5] == 'Fecha']
cols_medidas = ['MedicionPerimetroBraquial', 'Peso', 'Talla']
cols_zscore = [col for col in tom.columns if col[:6] == 'ZScore']
cols_estado = [col for col in tom.columns if col[:6] == 'Estado']
cols_zscore_peso = [col for col in tom.columns if col[:10] == 'ZScorePeso']
cols_estado_peso = [col for col in tom.columns if col[:10] == 'EstadoPeso']
for col in cols_cat:
  if str(tom[col].dtype) == 'category':
    print(f'\n ** {col} **')
    print(tom[col].value_counts(normalize=True, dropna=False))
# Out:
#  ** Vigencia **
# 2018    0.355224
# 2019    0.325344
# 2017    0.319432
# Name: Vigencia, dtype: float64
#
#  ** Toma **
# 3      0.253525
# 2      0.247413
# 4      0.246545
# 1      0.231485
# 1N     0.004039
# 2N     0.003694
# 3N     0.003081
# 4N     0.002768
# 5N     0.002265
# 6N     0.001591
# 7N     0.001264
# 8N     0.000946
# 9N     0.000710
# 10N    0.000539
# 11N    0.000092
# 12N    0.000045
# Name: Toma, dtype: float64
#
#  ** Servicio **
# HCB TRADICIONAL- COMUNITARIO (T)                                                                  0.258447
# DESARROLLO INFANTIL EN MEDIO FAMILIAR SIN ARRIENDO - FAMILIAR INTEGRAL                            0.157157
# CDI SIN ARRIENDO -  INSTITUCIONAL INTEGRAL                                                        0.109048
# DESARROLLO INFANTIL EN MEDIO FAMILIAR CON ARRIENDO - FAMILIAR INTEGRAL                            0.092390
# HOGARES INFANTILES - INSTITUCIONAL INTEGRAL                                                       0.063899
# HCB FAMI-FAMILIAR TRADICIONAL                                                                     0.057703
# CDI CON ARRIENDO - INSTITUCIONAL INTEGRAL                                                         0.053520
# ATENCIÓN PROPIA E INTERCULTURAL                                                                   0.042383
# SERVICIO ESPECIAL PARA LA PRIMERA INFANCIA - INSTITUCIONAL INTEGRAL                               0.036979
# SERVICIO ESPECIAL PARA LA PRIMERA INFANCIA - FAMILIAR INTEGRAL                                    0.035047
# HCB INTEGRAL -COMUNITARIO  INTEGRAL                                                               0.027524
# HCB  AGRUPADOS -INSTITUCIONAL TRADICIONAL                                                         0.021808
# ESTRATEGIAS DE DESARROLLO ALIMENTARIO O NUTRICIONAL (MODALIDAD MIL DÍAS PARA CAMBIAR EL MUNDO)    0.020584
# SERVICIO ESPECIAL PARA LA PRIMERA INFANCIA - GRADO TRANSICIÓN CON ATENCIÓN INTEGRAL               0.012397
# SERVICIO ESPECIAL PARA LA PRIMERA INFANCIA  - COMUNITARIO INTEGRAL                                0.008721
# JARDINES SOCIALES - INSTITUCIONAL INTEGRAL                                                        0.000852
# HOGARES EMPRESARIALES - INSTITUCIONAL INTEGRAL                                                    0.000607
# NaN                                                                                               0.000448
# SERVICIO ESPECIAL PARA LA PRIMERA INFANCIA - ATENCIÓN PROPIA E INTERCULTURAL                      0.000314
# HOGARES MULTIPLES - INSTITUCIONAL INTEGRAL                                                        0.000104
# ATENCIÓN A NIÑOS HASTA LOS 3 AÑOS EN ESTABLECIMIENTOS DE RECLUSIÓN A MUJERES INTEGRAL             0.000036
# DESARROLLO INFANTIL EN MEDIO FAMILIAR - FAMILIAR INTEGRAL                                         0.000031
# CENTROS DE RECUPERACIÓN NUTRICIONAL PARA LA PRIMERA INFANCIA                                      0.000000
# Name: Servicio, dtype: float64
#
#  ** EstadoTallaEdad **
# Talla adecuada para la edad        0.564098
# Riesgo de baja talla               0.275707
# Retraso en talla                   0.158736
# NaN                                0.001459
# Talla por encima de lo esperado    0.000000
# Name: EstadoTallaEdad, dtype: float64
#
#  ** EstadoPesoEdad **
# Peso adecuado para la edad          0.679080
# Riesgo de peso bajo para la edad    0.149584
# NaN                                 0.097645
# Sobrepeso                           0.031531
# Desnutrición global                 0.027548
# Obesidad                            0.007505
# Desnutrición global severa          0.007107
# Name: EstadoPesoEdad, dtype: float64
#
#  ** EstadoPesoTalla **
# Peso adecuado para la talla     0.662338
# Riesgo de sobrepeso             0.165545
# Riesgo de desnutrición aguda    0.055877
# NaN                             0.047364
# Sobrepeso                       0.042032
# Obesidad                        0.014200
# Desnutrición aguda moderada     0.009261
# Desnutrición aguda severa       0.003383
# Name: EstadoPesoTalla, dtype: float64
#
#  ** EstadoIMC **
# Adecuado para la edad      0.663519
# Riesgo de sobrepeso        0.185522
# Sobrepeso                  0.058272
# Riesgo para la delgadez    0.057349
# Obesidad                   0.019790
# Delgadez                   0.014089
# NaN                        0.001459
# Name: EstadoIMC, dtype: float64
#
#  ** PresentaCarneVacunacion **
# S      0.980479
# N      0.019496
# NaN    0.000025
# Name: PresentaCarneVacunacion, dtype: float64
#
#  ** AntecedentePremadurez **
# NaN    0.989778
# N      0.010055
# S      0.000167
# Name: AntecedentePremadurez, dtype: float64
#
#  ** Direccion **
# Primera Infancia    0.978967
# Nutrición           0.021033
# Name: Direccion, dtype: float64

# %%
time0 = time.time()# Analizar las dos tomas anteriores
cols_imp = ['FechaValoracionNutricional', 'EdadMeses',
       'FechaMedicionPerimetroBraquial', 'MedicionPerimetroBraquial', 'Peso',
       'Talla', 'ZScoreTallaEdad', 'ZScorePesoEdad', 'ZScorePesoTalla',
       'ZScoreIMC', 'EstadoTallaEdad', 'EstadoPesoEdad', 'EstadoPesoTalla',
       'EstadoIMC', 'PresentaCarneVacunacion', 'ControlesCrecimDesarrollo']
prof = 2
cols_his = [col + '-' + str(prof - i) for i in range(prof + 1) for col in cols_imp] 
his_list = list()
len_melted = len(cols_prof)

ids_recuperacion = set(reincidencia.loc[reincidencia['recuperacion'], 'IdBeneficiario'])
#nuevo_ben = True
#presenta_desnutricion = False
for i in range(prof, len(tom)):
  id = tom.loc[i, 'IdBeneficiario']
  if (tom.loc[i - prof, 'IdBeneficiario'] == id) and (id in ids_recuperacion):
    fragmento = tom[i - prof: i + 1].reset_index(drop=True).\
      reset_index()
    melted = fragmento.melt(id_vars='index', value_vars=cols_imp)
    melted['varname'] = melted.\
      apply(lambda x: x['variable'] + '-' + str(prof - x['index']), axis='columns')
    melted['IdBeneficiario'] = [id] * len_melted
    pivot = melted.pivot(index='IdBeneficiario', columns='varname', values='value').\
      reset_index(drop=False)
    his_list.append(pivot)
    if i % 1e6 == 0:
      print(f'Toma {i}/{len(tom)}, {len(his)} fragmentos extraidos: ' +
            f'{time.time() - time0:.2f} s.')
his = pd.concat(his_list, axis='index')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-2264bf20f750> in <module>()
#      10 len_melted = len(cols_prof)
#      11
# ---> 12 ids_recuperacion = set(reincidencia.loc[reincidencia['recuperacion'], 'IdBeneficiario'])
#      13 #nuevo_ben = True
#      14 #presenta_desnutricion = False
#
# NameError: name 'reincidencia' is not defined

# %%
his_prof_2.to_parquet('historical_data/historia_prof_2')

# %%
his_prof_2 = pd.read_parquet('historical_data/historia_prof_2')

# %%
his = his_prof_2[cols_his + ['IdBeneficiario']]

# %%
#Quitar las fechas, 'PresentaCarneVacunacion',  'ControlesCrecimDesarrollo'
his = his.drop(columns=[col for col in his.columns if col[:5] == 'Fecha'])
his = his.drop(columns=[col for col in his.columns if col[:8] == 'Presenta'])
his = his.drop(columns=[col for col in his.columns if col[:9] == 'Controles'])
# Quitar las características que no se quieren predecir
quit = [col for col in his.columns if col[-1] == '0' \
        and col not in ('EstadoPesoTalla-0', 'EdadMeses-0')]
his = his.drop(columns=quit)

# %%
his['tiempo'] = his['EdadMeses-0'] - his['EdadMeses-1']
his[]

# %%
for col in cols_estado:
  his[col] = his[col].astype('category').\
    cat.set_categories(tom_cat[col[:-2]], ordered=True)

# %%
his['CodigoPesoTalla'] = his['EstadoPesoTalla-0'].cat.codes
his['Desnutricion'] = his['CodigoPesoTalla'].isin([0, 1])

# %%
idB_desnutricion = his[his['Desnutricion']]['IdBeneficiario']
his = his[his['IdBeneficiario'].isin(idB_desnutricion)]

# %%
# Cruza con sociodemográficos (se pierden la mitad de los datos)
join = soc.merge(his, how='inner', on='IdBeneficiario')
join.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24711 entries, 0 to 24710
# Data columns (total 97 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Cod_clase                    24711 non-null  category
#  1   Ind_grupo_sisben_4           24711 non-null  category
#  2   Ind_nivel_sisben_4           24711 non-null  category
#  3   Tip_vivienda                 24711 non-null  category
#  4   Ind_tiene_energia            24711 non-null  category
#  5   Ind_tiene_alcantarillado     24711 non-null  category
#  6   Ind_tiene_gas                24711 non-null  category
#  7   Ind_tiene_recoleccion        24711 non-null  category
#  8   Ind_tiene_acueducto          24711 non-null  category
#  9   n_hogares_vivienda           24711 non-null  UInt8
#  10  Tip_ocupa_vivienda           24711 non-null  category
#  11  Ind_tiene_cocina             24711 non-null  category
#  12  Ind_tiene_nevera             24711 non-null  category
#  13  Ind_tiene_lavadora           24711 non-null  category
#  14  Ind_tiene_pc                 24711 non-null  category
#  15  Ind_tiene_internet           24711 non-null  category
#  16  n_personas_hogar             24711 non-null  UInt8
#  17  Sexo                         24711 non-null  category
#  18  Ind_ninguna_discapac         24711 non-null  category
#  19  Tip_seg_social               24711 non-null  category
#  20  Ind_acudio_salud             3394 non-null   category
#  21  Ind_fue_atendido_salud       2978 non-null   category
#  22  Tip_cuidado_ninos            24711 non-null  category
#  23  Ind_recibe_comida            19589 non-null  category
#  24  Ind_leer_escribir            5122 non-null   category
#  25  Ind_estudia                  24711 non-null  category
#  26  privado_logro_educ           24711 non-null  category
#  27  privado_analfabe             24711 non-null  category
#  28  privado_inasistencia         24711 non-null  category
#  29  privado_rezago               24711 non-null  category
#  30  privado_primera_inf          24711 non-null  category
#  31  privado_trabajo_inf          24711 non-null  category
#  32  privado_desemp_largo         24711 non-null  category
#  33  privado_trabajo_info         24711 non-null  category
#  34  privado_aseguram             24711 non-null  category
#  35  privado_acceso_salud         24711 non-null  category
#  36  privado_agua                 24711 non-null  category
#  37  privado_excreta              24711 non-null  category
#  38  privado_suelo                24711 non-null  category
#  39  privado_pared                24711 non-null  category
#  40  privado_hacina               24711 non-null  category
#  41  n_privaciones                24711 non-null  float32
#  42  IndicadorPobrezaMulti        24711 non-null  category
#  43  ingresos_promP_imp           24711 non-null  float32
#  44  gasto_ppers_imp              24711 non-null  float32
#  45  gasto_alim_ppers_imp         24711 non-null  float32
#  46  porc_gasto_alim              24711 non-null  float32
#  47  union_temprana               24711 non-null  category
#  48  n_ninos                      24711 non-null  UInt8
#  49  Tip_hijo                     24711 non-null  category
#  50  Jefat_fem                    24711 non-null  category
#  51  Tip_familia                  24711 non-null  category
#  52  Genera_ingresos              24711 non-null  category
#  53  Nivel_educ_padre             15586 non-null  category
#  54  Nivel_educ_madre             23502 non-null  category
#  55  anno_encuesta                24711 non-null  category
#  56  Uni_dias_agua                24711 non-null  float32
#  57  Ind_afec_evento_natural      24711 non-null  category
#  58  n_afec_evento_natural        24711 non-null  UInt8
#  59  Edad_padres_mayor            24711 non-null  UInt8
#  60  Edad_padres_menor            24711 non-null  UInt8
#  61  Comparte_cocina_sanitario    24711 non-null  category
#  62  Estrato                      24711 non-null  category
#  63  cod_mpio                     24711 non-null  category
#  64  cod_dpto                     24711 non-null  category
#  65  FechaNacimiento              24711 non-null  datetime64[ns]
#  66  IdBeneficiario               24711 non-null  UInt32
#  67  Id                           24711 non-null  UInt32
#  68  EdadMeses-2                  24710 non-null  float64
#  69  MedicionPerimetroBraquial-2  5477 non-null   float64
#  70  Peso-2                       24711 non-null  float64
#  71  Talla-2                      24711 non-null  float64
#  72  ZScoreTallaEdad-2            24356 non-null  float64
#  73  ZScorePesoEdad-2             24537 non-null  float64
#  74  ZScorePesoTalla-2            24256 non-null  float64
#  75  ZScoreIMC-2                  24250 non-null  float64
#  76  EstadoTallaEdad-2            24647 non-null  category
#  77  EstadoPesoEdad-2             24333 non-null  category
#  78  EstadoPesoTalla-2            24564 non-null  category
#  79  EstadoIMC-2                  24647 non-null  category
#  80  EdadMeses-1                  24711 non-null  float64
#  81  MedicionPerimetroBraquial-1  5971 non-null   float64
#  82  Peso-1                       24711 non-null  float64
#  83  Talla-1                      24711 non-null  float64
#  84  ZScoreTallaEdad-1            24415 non-null  float64
#  85  ZScorePesoEdad-1             24315 non-null  float64
#  86  ZScorePesoTalla-1            24178 non-null  float64
#  87  ZScoreIMC-1                  24394 non-null  float64
#  88  EstadoTallaEdad-1            24623 non-null  category
#  89  EstadoPesoEdad-1             24055 non-null  category
#  90  EstadoPesoTalla-1            24329 non-null  category
#  91  EstadoIMC-1                  24623 non-null  category
#  92  EdadMeses-0                  24711 non-null  float64
#  93  EstadoPesoTalla-0            23770 non-null  category
#  94  tiempo                       24711 non-null  float64
#  95  CodigoPesoTalla              24711 non-null  int8
#  96  Desnutricion                 24711 non-null  bool
# dtypes: UInt32(2), UInt8(6), bool(1), category(62), datetime64[ns](1), float32(6), float64(18), int8(1)
# memory usage: 6.4 MB

# %%
# Descarta tomas muy seguidas o fechas absurdas
his = his[his['tiempo'] > 0]
his_tiempo = list()
for i in range(4):
  his_tiempo.append(his[his['tiempo'] == i + 1].drop(columns=['tiempo']))

join = join[join['tiempo'] > 0]
join_tiempo = list()
for i in range(4):
  join_tiempo.append(join[join['tiempo'] == i + 1].drop(columns=['tiempo']))

his['tiempo'].value_counts()[:10]
# Out:
# 3.0     13739
# 2.0      4201
# 4.0      3088
# 1.0      2175
# 5.0       348
# 6.0       234
# 7.0       125
# 9.0        94
# 10.0       67
# Name: tiempo, dtype: int64

# %%
# Realiza conjuntos de entrenamiento y prueba para este conjunto
IdB_train = joblib.load('auxiliary_data/IdBeneficiario_train.pickle')
IdB_test = joblib.load('auxiliary_data/IdBeneficiario_test.pickle')


his_train = his[his['IdBeneficiario'].isin(IdB_train)]
his_test = his[his['IdBeneficiario'].isin(IdB_test)]
print(len(his_train), len(his_test))

join_train = join[join['IdBeneficiario'].isin(IdB_train)]
join_test = join[join['IdBeneficiario'].isin(IdB_test)]
print(len(join_train), len(join_test))
# Out:
# 19729 5002
# 19714 4997

# %%
join.to_parquet('historical_data/sociodemo_historia_2.parquet')
join_train.to_parquet('historical_data/sociodemo_historia_2_train.parquet')
join_test.to_parquet('historical_data/sociodemo_historia_2_test.parquet')

his.to_parquet('historical_data/historia_2.parquet')
his_train.to_parquet('historical_data/historia_2_train.parquet')
his_test.to_parquet('historical_data/historia_2_test.parquet')
